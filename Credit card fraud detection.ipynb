# %%
import numpy as np
import pandas as pd

# %%
data =  pd.read_csv('creditcard.csv')

# %% [markdown]
# # 1. Data Cleaning

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data = data.drop(['Time'],axis=1)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
data.duplicated().sum()
# Out:
# 9144

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(data['Class'].value_counts(), labels=['legit','fraud'],autopct="%0.2f")
plt.show()

# %% [markdown]
# #### Data set is highly imbalanced

# %% [markdown]
# ## Using Under Sampling technique

# %%
normal = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
new_data = pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.329987  1.126482  1.357256  0.662498  0.467458 -0.195716  0.810952
# 1 -0.125018 -0.110879  1.273493 -1.882157 -1.073641  0.154987 -0.830513
# 2  2.090351  0.071174 -1.455661  0.255064  0.306802 -1.021216  0.328091
# 3 -0.493603  1.327704  0.606132  0.849631  0.213186 -0.296504  0.485725
# 4  1.200409  0.347976  0.423199  0.619850 -0.366524 -0.852674  0.022307
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0 -0.065880 -1.154163 -0.137177  ...  0.183927  0.591597 -0.292251  0.056191
# 1  0.285659 -0.158296  0.052915  ...  0.471639  1.476640 -0.117359 -0.592099
# 2 -0.430724  0.422355 -0.032390  ...  0.240882  0.932104 -0.061296 -0.345257
# 3  0.305116 -0.857232 -0.397492  ...  0.150208  0.346677 -0.194451 -0.451203
# 4 -0.098781 -0.318790 -0.128954  ... -0.216942 -0.637723  0.136307  0.509464
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
new_data.tail()
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 941 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 942  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 943 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 944 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 945  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
#            V8        V9       V10  ...       V21       V22       V23  \
# 941  0.697211 -2.064945 -5.587794  ...  0.778584 -0.319189  0.639419
# 942  0.248525 -1.127396 -3.232153  ...  0.370612  0.028234 -0.145640
# 943  1.210158 -0.652250 -3.463891  ...  0.751826  0.834108  0.190944
# 944  1.058733 -1.632333 -5.245984  ...  0.583276 -0.269209 -0.456108
# 945 -0.068384  0.577829 -0.888722  ... -0.164350 -0.295135 -0.072173
#
#           V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
X = new_data.drop('Class',axis=1)
y = new_data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20, stratify=y, random_state=2)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9315789473684211

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9361702127659575

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9263157894736842

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9312169312169312

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.8736842105263158

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.8380952380952381

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9263157894736842

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.88

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9263157894736842

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.945054945054945

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9052631578947369

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9247311827956989

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF'],
                            "ACC":[accuracy_score(y_test,y_pred1),accuracy_score(y_test,y_pred2),accuracy_score(y_test,y_pred3)],
                            "Prec":[precision_score(y_test,y_pred1),precision_score(y_test,y_pred2),precision_score(y_test,y_pred3)],
                            "F_1":[f1_score(y_test,y_pred1),f1_score(y_test,y_pred2),f1_score(y_test,y_pred3)]})

# %%
final_data
# Out:
#   Models       ACC      Prec       F_1
# 0     LR  0.931579  0.936170  0.931217
# 1     DT  0.873684  0.838095  0.880000
# 2     RF  0.926316  0.945055  0.924731

# %% [markdown]
# #### Logistic regressin is performing best on undersampling data

# %% [markdown]
# ## Over sampling Using SMOTE

# %%
X = data.drop('Class',axis=1)
y = data['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
# !pip install --upgrade imbalanced-learn
# Out:
# ...
#    ---------------------------------------- 0.0/238.4 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/238.4 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 238.4/238.4 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.11.0
#     Uninstalling imbalanced-learn-0.11.0:
#       Successfully uninstalled imbalanced-learn-0.11.0
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res,y_res = SMOTE().fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_res,y_res,test_size=0.20, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %%
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9453559358988335

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9730032442453267

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9160591240477792

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9436729189882663

# %% [markdown]
# ### Decision Tree Classifier

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9980558886587448

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9972771333660078

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9988364271039761

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9980561712022672

# %% [markdown]
# ### Random Forest classifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.999918238308078

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9998363993310551

# %%
recall_score(y_test,y_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9999181929736854

# %%
final_data_2 = pd.DataFrame({'Models':['LR','DT','RF'],
                            "ACC":[accuracy_score(y_test,y_pred1),accuracy_score(y_test,y_pred2),accuracy_score(y_test,y_pred3)],
                            "Prec":[precision_score(y_test,y_pred1),precision_score(y_test,y_pred2),precision_score(y_test,y_pred3)],
                            "F_1":[f1_score(y_test,y_pred1),f1_score(y_test,y_pred2),f1_score(y_test,y_pred3)]})

# %%
final_data_2
# Out:
#   Models       ACC      Prec       F_1
# 0     LR  0.945356  0.973003  0.943673
# 1     DT  0.998056  0.997277  0.998056
# 2     RF  0.999918  0.999836  0.999918

# %% [markdown]
# #### Random forest is performing best on oversampled data
